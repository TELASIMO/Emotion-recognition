# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages (2.4.3)
# Requirement already satisfied: numpy>=1.9.1 in /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages (from keras) (1.19.2)
# Requirement already satisfied: h5py in /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages (from keras) (2.10.0)
# Requirement already satisfied: pyyaml in /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages (from keras) (5.4.1)
# Requirement already satisfied: scipy>=0.14 in /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages (from keras) (1.6.1)
# Requirement already satisfied: six in /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages (from h5py->keras) (1.15.0)

# %%
"""
    A simple neural network written in Keras (TensorFlow backend) to classify the IRIS data
"""

import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

iris_data = load_iris() # load the iris dataset

print('Example data: ')
print(iris_data.data[:5])
print('Example labels: ')
print(iris_data.target[:5])

x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column

# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)
#print(y)

# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# Build the model

model = Sequential()

model.add(Dense(10, input_shape=(4,), activation='relu', name='fc1'))
model.add(Dense(10, activation='relu', name='fc2'))
model.add(Dense(3, activation='softmax', name='output'))

# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())

# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)

# Test on unseen data

results = model.evaluate(test_x, test_y)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# Example data:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# Example labels:
# [0 0 0 0 0]
# Neural Network Model Summary:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 10)                50
# _________________________________________________________________
# fc2 (Dense)                  (None, 10)                110
# _________________________________________________________________
# output (Dense)               (None, 3)                 33
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 24/24 - 2s - loss: 1.3348 - accuracy: 0.3500
# Epoch 2/200
# 24/24 - 0s - loss: 1.1955 - accuracy: 0.4667
# Epoch 3/200
# 24/24 - 0s - loss: 1.1071 - accuracy: 0.3917
# Epoch 4/200
# 24/24 - 0s - loss: 1.0273 - accuracy: 0.3500
# Epoch 5/200
# 24/24 - 0s - loss: 0.9588 - accuracy: 0.3333
# Epoch 6/200
# 24/24 - 0s - loss: 0.8939 - accuracy: 0.4333
# Epoch 7/200
# 24/24 - 0s - loss: 0.8345 - accuracy: 0.6500
# Epoch 8/200
# 24/24 - 0s - loss: 0.7762 - accuracy: 0.6667
# Epoch 9/200
# 24/24 - 0s - loss: 0.7149 - accuracy: 0.6833
# Epoch 10/200
# 24/24 - 0s - loss: 0.6656 - accuracy: 0.6750
# Epoch 11/200
# 24/24 - 0s - loss: 0.6233 - accuracy: 0.7583
# Epoch 12/200
# 24/24 - 0s - loss: 0.5783 - accuracy: 0.7167
# Epoch 13/200
# 24/24 - 0s - loss: 0.5446 - accuracy: 0.8167
# Epoch 14/200
# 24/24 - 0s - loss: 0.5102 - accuracy: 0.8583
# Epoch 15/200
# 24/24 - 0s - loss: 0.4827 - accuracy: 0.8833
# Epoch 16/200
# 24/24 - 0s - loss: 0.4546 - accuracy: 0.9000
# Epoch 17/200
# 24/24 - 0s - loss: 0.4284 - accuracy: 0.9167
# Epoch 18/200
# 24/24 - 0s - loss: 0.4064 - accuracy: 0.9333
# Epoch 19/200
# 24/24 - 0s - loss: 0.3885 - accuracy: 0.9417
# Epoch 20/200
# 24/24 - 0s - loss: 0.3742 - accuracy: 0.9083
# Epoch 21/200
# 24/24 - 0s - loss: 0.3529 - accuracy: 0.9500
# Epoch 22/200
# 24/24 - 0s - loss: 0.3374 - accuracy: 0.9333
# Epoch 23/200
# 24/24 - 0s - loss: 0.3236 - accuracy: 0.9250
# Epoch 24/200
# 24/24 - 0s - loss: 0.3076 - accuracy: 0.9500
# Epoch 25/200
# 24/24 - 0s - loss: 0.2965 - accuracy: 0.9500
# Epoch 26/200
# 24/24 - 0s - loss: 0.2811 - accuracy: 0.9583
# Epoch 27/200
# 24/24 - 0s - loss: 0.2716 - accuracy: 0.9583
# Epoch 28/200
# 24/24 - 0s - loss: 0.2585 - accuracy: 0.9583
# Epoch 29/200
# 24/24 - 0s - loss: 0.2523 - accuracy: 0.9750
# Epoch 30/200
# 24/24 - 0s - loss: 0.2412 - accuracy: 0.9583
# Epoch 31/200
# 24/24 - 0s - loss: 0.2307 - accuracy: 0.9667
# Epoch 32/200
# 24/24 - 0s - loss: 0.2223 - accuracy: 0.9583
# Epoch 33/200
# 24/24 - 0s - loss: 0.2120 - accuracy: 0.9583
# Epoch 34/200
# 24/24 - 0s - loss: 0.2085 - accuracy: 0.9833
# Epoch 35/200
# 24/24 - 0s - loss: 0.1994 - accuracy: 0.9750
# Epoch 36/200
# 24/24 - 0s - loss: 0.1954 - accuracy: 0.9750
# Epoch 37/200
# 24/24 - 0s - loss: 0.1887 - accuracy: 0.9667
# Epoch 38/200
# 24/24 - 0s - loss: 0.1894 - accuracy: 0.9417
# Epoch 39/200
# 24/24 - 0s - loss: 0.1848 - accuracy: 0.9417
# Epoch 40/200
# 24/24 - 0s - loss: 0.1771 - accuracy: 0.9417
# Epoch 41/200
# 24/24 - 0s - loss: 0.1687 - accuracy: 0.9750
# Epoch 42/200
# 24/24 - 0s - loss: 0.1649 - accuracy: 0.9750
# Epoch 43/200
# 24/24 - 0s - loss: 0.1604 - accuracy: 0.9750
# Epoch 44/200
# 24/24 - 0s - loss: 0.1612 - accuracy: 0.9583
# Epoch 45/200
# 24/24 - 0s - loss: 0.1538 - accuracy: 0.9750
# Epoch 46/200
# 24/24 - 0s - loss: 0.1456 - accuracy: 0.9833
# Epoch 47/200
# 24/24 - 0s - loss: 0.1426 - accuracy: 0.9750
# Epoch 48/200
# 24/24 - 0s - loss: 0.1398 - accuracy: 0.9750
# Epoch 49/200
# 24/24 - 0s - loss: 0.1356 - accuracy: 0.9833
# Epoch 50/200
# 24/24 - 0s - loss: 0.1350 - accuracy: 0.9833
# Epoch 51/200
# 24/24 - 0s - loss: 0.1337 - accuracy: 0.9667
# Epoch 52/200
# 24/24 - 0s - loss: 0.1280 - accuracy: 0.9750
# Epoch 53/200
# 24/24 - 0s - loss: 0.1250 - accuracy: 0.9750
# Epoch 54/200
# 24/24 - 0s - loss: 0.1226 - accuracy: 0.9917
# Epoch 55/200
# 24/24 - 0s - loss: 0.1220 - accuracy: 0.9750
# Epoch 56/200
# 24/24 - 0s - loss: 0.1218 - accuracy: 0.9667
# Epoch 57/200
# 24/24 - 0s - loss: 0.1167 - accuracy: 0.9917
# Epoch 58/200
# 24/24 - 0s - loss: 0.1167 - accuracy: 0.9750
# Epoch 59/200
# 24/24 - 0s - loss: 0.1137 - accuracy: 0.9750
# Epoch 60/200
# 24/24 - 0s - loss: 0.1130 - accuracy: 0.9750
# Epoch 61/200
# 24/24 - 0s - loss: 0.1138 - accuracy: 0.9750
# Epoch 62/200
# 24/24 - 0s - loss: 0.1103 - accuracy: 0.9750
# Epoch 63/200
# 24/24 - 0s - loss: 0.1070 - accuracy: 0.9833
# Epoch 64/200
# 24/24 - 0s - loss: 0.1068 - accuracy: 0.9750
# Epoch 65/200
# 24/24 - 0s - loss: 0.1044 - accuracy: 0.9833
# Epoch 66/200
# 24/24 - 0s - loss: 0.0997 - accuracy: 0.9750
# Epoch 67/200
# 24/24 - 0s - loss: 0.1028 - accuracy: 0.9833
# Epoch 68/200
# 24/24 - 0s - loss: 0.1028 - accuracy: 0.9750
# Epoch 69/200
# 24/24 - 0s - loss: 0.0967 - accuracy: 0.9750
# Epoch 70/200
# 24/24 - 0s - loss: 0.0958 - accuracy: 0.9833
# Epoch 71/200
# 24/24 - 0s - loss: 0.0964 - accuracy: 0.9750
# Epoch 72/200
# 24/24 - 0s - loss: 0.0947 - accuracy: 0.9750
# Epoch 73/200
# 24/24 - 0s - loss: 0.0922 - accuracy: 0.9750
# Epoch 74/200
# 24/24 - 0s - loss: 0.0905 - accuracy: 0.9750
# Epoch 75/200
# 24/24 - 0s - loss: 0.1003 - accuracy: 0.9667
# Epoch 76/200
# 24/24 - 0s - loss: 0.0900 - accuracy: 0.9750
# Epoch 77/200
# 24/24 - 0s - loss: 0.0893 - accuracy: 0.9750
# Epoch 78/200
# 24/24 - 0s - loss: 0.0872 - accuracy: 0.9750
# Epoch 79/200
# 24/24 - 0s - loss: 0.0887 - accuracy: 0.9833
# Epoch 80/200
# 24/24 - 0s - loss: 0.0837 - accuracy: 0.9833
# Epoch 81/200
# 24/24 - 0s - loss: 0.0870 - accuracy: 0.9833
# Epoch 82/200
# 24/24 - 0s - loss: 0.0871 - accuracy: 0.9750
# Epoch 83/200
# 24/24 - 0s - loss: 0.0833 - accuracy: 0.9750
# Epoch 84/200
# 24/24 - 0s - loss: 0.0848 - accuracy: 0.9833
# Epoch 85/200
# 24/24 - 0s - loss: 0.0856 - accuracy: 0.9750
# Epoch 86/200
# 24/24 - 0s - loss: 0.0803 - accuracy: 0.9833
# Epoch 87/200
# 24/24 - 0s - loss: 0.0845 - accuracy: 0.9750
# Epoch 88/200
# 24/24 - 0s - loss: 0.0864 - accuracy: 0.9667
# Epoch 89/200
# 24/24 - 0s - loss: 0.0784 - accuracy: 0.9833
# Epoch 90/200
# 24/24 - 0s - loss: 0.0856 - accuracy: 0.9667
# Epoch 91/200
# 24/24 - 0s - loss: 0.0918 - accuracy: 0.9750
# Epoch 92/200
# 24/24 - 0s - loss: 0.0861 - accuracy: 0.9750
# Epoch 93/200
# 24/24 - 0s - loss: 0.0801 - accuracy: 0.9750
# Epoch 94/200
# 24/24 - 0s - loss: 0.0794 - accuracy: 0.9833
# Epoch 95/200
# 24/24 - 0s - loss: 0.0778 - accuracy: 0.9833
# Epoch 96/200
# 24/24 - 0s - loss: 0.0760 - accuracy: 0.9750
# Epoch 97/200
# 24/24 - 0s - loss: 0.0777 - accuracy: 0.9750
# Epoch 98/200
# 24/24 - 0s - loss: 0.0774 - accuracy: 0.9750
# Epoch 99/200
# 24/24 - 0s - loss: 0.0856 - accuracy: 0.9583
# Epoch 100/200
# 24/24 - 0s - loss: 0.0952 - accuracy: 0.9500
# Epoch 101/200
# 24/24 - 0s - loss: 0.0760 - accuracy: 0.9750
# Epoch 102/200
# 24/24 - 0s - loss: 0.0711 - accuracy: 0.9917
# Epoch 103/200
# 24/24 - 0s - loss: 0.0694 - accuracy: 0.9833
# Epoch 104/200
# 24/24 - 0s - loss: 0.0705 - accuracy: 0.9750
# Epoch 105/200
# 24/24 - 0s - loss: 0.0736 - accuracy: 0.9833
# Epoch 106/200
# 24/24 - 0s - loss: 0.0706 - accuracy: 0.9833
# Epoch 107/200
# 24/24 - 0s - loss: 0.0683 - accuracy: 0.9833
# Epoch 108/200
# 24/24 - 0s - loss: 0.0666 - accuracy: 0.9833
# Epoch 109/200
# 24/24 - 0s - loss: 0.0733 - accuracy: 0.9750
# Epoch 110/200
# 24/24 - 0s - loss: 0.0676 - accuracy: 0.9750
# Epoch 111/200
# 24/24 - 0s - loss: 0.0665 - accuracy: 0.9750
# Epoch 112/200
# 24/24 - 0s - loss: 0.0706 - accuracy: 0.9833
# Epoch 113/200
# 24/24 - 0s - loss: 0.0708 - accuracy: 0.9750
# Epoch 114/200
# 24/24 - 0s - loss: 0.0743 - accuracy: 0.9833
# Epoch 115/200
# 24/24 - 0s - loss: 0.0743 - accuracy: 0.9583
# Epoch 116/200
# 24/24 - 0s - loss: 0.0772 - accuracy: 0.9750
# Epoch 117/200
# 24/24 - 0s - loss: 0.0638 - accuracy: 0.9917
# Epoch 118/200
# 24/24 - 0s - loss: 0.0659 - accuracy: 0.9750
# Epoch 119/200
# 24/24 - 0s - loss: 0.0651 - accuracy: 0.9917
# Epoch 120/200
# 24/24 - 0s - loss: 0.0691 - accuracy: 0.9833
# Epoch 121/200
# 24/24 - 0s - loss: 0.0658 - accuracy: 0.9750
# Epoch 122/200
# 24/24 - 0s - loss: 0.0672 - accuracy: 0.9833
# Epoch 123/200
# 24/24 - 0s - loss: 0.0623 - accuracy: 0.9750
# Epoch 124/200
# 24/24 - 0s - loss: 0.0622 - accuracy: 0.9917
# Epoch 125/200
# 24/24 - 0s - loss: 0.0629 - accuracy: 0.9833
# Epoch 126/200
# 24/24 - 0s - loss: 0.0632 - accuracy: 0.9917
# Epoch 127/200
# 24/24 - 0s - loss: 0.0612 - accuracy: 0.9833
# Epoch 128/200
# 24/24 - 0s - loss: 0.0615 - accuracy: 0.9833
# Epoch 129/200
# 24/24 - 0s - loss: 0.0607 - accuracy: 0.9917
# Epoch 130/200
# 24/24 - 0s - loss: 0.0652 - accuracy: 0.9750
# Epoch 131/200
# 24/24 - 0s - loss: 0.0676 - accuracy: 0.9667
# Epoch 132/200
# 24/24 - 0s - loss: 0.0592 - accuracy: 0.9750
# Epoch 133/200
# 24/24 - 0s - loss: 0.0609 - accuracy: 0.9833
# Epoch 134/200
# 24/24 - 0s - loss: 0.0617 - accuracy: 0.9833
# Epoch 135/200
# 24/24 - 0s - loss: 0.0606 - accuracy: 0.9833
# Epoch 136/200
# 24/24 - 0s - loss: 0.0604 - accuracy: 0.9667
# Epoch 137/200
# 24/24 - 0s - loss: 0.0599 - accuracy: 0.9750
# Epoch 138/200
# 24/24 - 0s - loss: 0.0580 - accuracy: 0.9917
# Epoch 139/200
# 24/24 - 0s - loss: 0.0592 - accuracy: 0.9833
# Epoch 140/200
# 24/24 - 0s - loss: 0.0569 - accuracy: 0.9833
# Epoch 141/200
# 24/24 - 0s - loss: 0.0629 - accuracy: 0.9833
# Epoch 142/200
# 24/24 - 0s - loss: 0.0608 - accuracy: 0.9833
# Epoch 143/200
# 24/24 - 0s - loss: 0.0555 - accuracy: 0.9917
# Epoch 144/200
# 24/24 - 0s - loss: 0.0594 - accuracy: 0.9833
# Epoch 145/200
# 24/24 - 0s - loss: 0.0588 - accuracy: 0.9833
# Epoch 146/200
# 24/24 - 0s - loss: 0.0586 - accuracy: 0.9833
# Epoch 147/200
# 24/24 - 0s - loss: 0.0598 - accuracy: 0.9750
# Epoch 148/200
# 24/24 - 0s - loss: 0.0604 - accuracy: 0.9750
# Epoch 149/200
# 24/24 - 0s - loss: 0.0586 - accuracy: 0.9833
# Epoch 150/200
# 24/24 - 0s - loss: 0.0579 - accuracy: 0.9833
# Epoch 151/200
# 24/24 - 0s - loss: 0.0588 - accuracy: 0.9833
# Epoch 152/200
# 24/24 - 0s - loss: 0.0577 - accuracy: 0.9917
# Epoch 153/200
# 24/24 - 0s - loss: 0.0613 - accuracy: 0.9917
# Epoch 154/200
# 24/24 - 0s - loss: 0.0532 - accuracy: 0.9833
# Epoch 155/200
# 24/24 - 0s - loss: 0.0542 - accuracy: 0.9917
# Epoch 156/200
# 24/24 - 0s - loss: 0.0535 - accuracy: 0.9833
# Epoch 157/200
# 24/24 - 0s - loss: 0.0535 - accuracy: 0.9833
# Epoch 158/200
# 24/24 - 0s - loss: 0.0535 - accuracy: 0.9833
# Epoch 159/200
# 24/24 - 0s - loss: 0.0531 - accuracy: 0.9833
# Epoch 160/200
# 24/24 - 0s - loss: 0.0559 - accuracy: 0.9917
# Epoch 161/200
# 24/24 - 0s - loss: 0.0544 - accuracy: 0.9750
# Epoch 162/200
# 24/24 - 0s - loss: 0.0555 - accuracy: 0.9917
# Epoch 163/200
# 24/24 - 0s - loss: 0.0585 - accuracy: 0.9750
# Epoch 164/200
# 24/24 - 0s - loss: 0.0601 - accuracy: 0.9833
# Epoch 165/200
# 24/24 - 0s - loss: 0.0553 - accuracy: 0.9750
# Epoch 166/200
# 24/24 - 0s - loss: 0.0565 - accuracy: 0.9917
# Epoch 167/200
# 24/24 - 0s - loss: 0.0543 - accuracy: 0.9917
# Epoch 168/200
# 24/24 - 0s - loss: 0.0540 - accuracy: 0.9833
# Epoch 169/200
# 24/24 - 0s - loss: 0.0557 - accuracy: 0.9833
# Epoch 170/200
# 24/24 - 0s - loss: 0.0522 - accuracy: 0.9833
# Epoch 171/200
# 24/24 - 0s - loss: 0.0534 - accuracy: 0.9917
# Epoch 172/200
# 24/24 - 0s - loss: 0.0505 - accuracy: 0.9917
# Epoch 173/200
# 24/24 - 0s - loss: 0.0495 - accuracy: 0.9833
# Epoch 174/200
# 24/24 - 0s - loss: 0.0511 - accuracy: 0.9833
# Epoch 175/200
# 24/24 - 0s - loss: 0.0498 - accuracy: 0.9917
# Epoch 176/200
# 24/24 - 0s - loss: 0.0497 - accuracy: 0.9833
# Epoch 177/200
# 24/24 - 0s - loss: 0.0541 - accuracy: 0.9833
# Epoch 178/200
# 24/24 - 0s - loss: 0.0501 - accuracy: 0.9833
# Epoch 179/200
# 24/24 - 0s - loss: 0.0499 - accuracy: 0.9833
# Epoch 180/200
# 24/24 - 0s - loss: 0.0486 - accuracy: 0.9833
# Epoch 181/200
# 24/24 - 0s - loss: 0.0491 - accuracy: 0.9833
# Epoch 182/200
# 24/24 - 0s - loss: 0.0547 - accuracy: 0.9833
# Epoch 183/200
# 24/24 - 0s - loss: 0.0531 - accuracy: 0.9833
# Epoch 184/200
# 24/24 - 0s - loss: 0.0487 - accuracy: 0.9833
# Epoch 185/200
# 24/24 - 0s - loss: 0.0493 - accuracy: 0.9833
# Epoch 186/200
# 24/24 - 0s - loss: 0.0473 - accuracy: 0.9917
# Epoch 187/200
# 24/24 - 0s - loss: 0.0489 - accuracy: 0.9833
# Epoch 188/200
# 24/24 - 0s - loss: 0.0509 - accuracy: 0.9833
# Epoch 189/200
# 24/24 - 0s - loss: 0.0493 - accuracy: 0.9833
# Epoch 190/200
# 24/24 - 0s - loss: 0.0559 - accuracy: 0.9833
# Epoch 191/200
# 24/24 - 0s - loss: 0.0537 - accuracy: 0.9833
# Epoch 192/200
# 24/24 - 0s - loss: 0.0489 - accuracy: 0.9833
# Epoch 193/200
# 24/24 - 0s - loss: 0.0478 - accuracy: 0.9833
# Epoch 194/200
# 24/24 - 0s - loss: 0.0511 - accuracy: 0.9750
# Epoch 195/200
# 24/24 - 0s - loss: 0.0514 - accuracy: 0.9833
# Epoch 196/200
# 24/24 - 0s - loss: 0.0485 - accuracy: 0.9833
# Epoch 197/200
# 24/24 - 0s - loss: 0.0473 - accuracy: 0.9833
# Epoch 198/200
# 24/24 - 0s - loss: 0.0524 - accuracy: 0.9917
# Epoch 199/200
# 24/24 - 0s - loss: 0.0469 - accuracy: 0.9917
# Epoch 200/200
# 24/24 - 0s - loss: 0.0462 - accuracy: 0.9833
# 1/1 [==============================] - 0s 355ms/step - loss: 0.1227 - accuracy: 0.9667
# Final test set loss: 0.122744
# Final test set accuracy: 0.966667

# %%
### Test sur le malware data

# %%
import pandas as pd
datamalw = pd.read_csv('data-train-model2021.csv')
datamalw.shape
# Out:
# (411, 46)

# %%
datamalw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411 entries, 0 to 410
# Data columns (total 46 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   items                                                      411 non-null    int64
#  1   CAMERA                                                     411 non-null    int64
#  2   GET_ACCOUNTS                                               411 non-null    int64
#  3   READ_CALENDAR                                              411 non-null    int64
#  4   READ_CALL_LOG                                              411 non-null    int64
#  5   READ_CONTACTS                                              411 non-null    int64
#  6   READ_EXTERNAL_STORAGE                                      410 non-null    float64
#  7   READ_PHONE_STATE                                           410 non-null    float64
#  8   READ_SMS                                                   411 non-null    int64
#  9   RECEIVE_SMS                                                411 non-null    int64
#  10  SEND_SMS                                                   411 non-null    int64
#  11  WRITE_CALENDAR                                             411 non-null    int64
#  12  WRITE_CALL_LOG                                             411 non-null    int64
#  13  ACCESS_MOCK_LOCATION                                       411 non-null    int64
#  14  ACCOUNT_MANAGER                                            411 non-null    int64
#  15  ACCESS_NETWORK_STATE                                       411 non-null    int64
#  16  READ_VOICEMAIL                                             410 non-null    float64
#  17  CAMERA/GET_ACCOUNTS                                        411 non-null    int64
#  18  Unnamed: 18                                                411 non-null    int64
#  19  GET_ACCOUNTS/READ_CALENDAR                                 411 non-null    int64
#  20  READ_CALENDAR/READ_CALL_LOG                                411 non-null    int64
#  21  READ_CALL_LOG/READ_CONTACTS                                411 non-null    int64
#  22  READ_CONTACTS/READ_EXTERNAL_STORAGE                        411 non-null    int64
#  23  READ_EXTERNAL_STORAGE/READ_PHONE_STATE                     411 non-null    int64
#  24  READ_SMS/RECEIVE_SMS                                       411 non-null    int64
#  25  RECEIVE_SMS/SEND_SMS                                       411 non-null    int64
#  26  SEND_SMS/WRITE_CALENDAR                                    411 non-null    int64
#  27  WRITE_CALENDAR/WRITE_CALL_LOG                              411 non-null    int64
#  28  WRITE_CALL_LOG
# ACCESS_MOCK_LOCATION                        411 non-null    int64
#  29  permi                                                      411 non-null    int64
#  30  ACCESS_NETWORK_STATE
# READ_VOICEMAIL                        411 non-null    int64
#  31  CAMERA
# GET_ACCOUNTS
# READ_CALENDAR                          411 non-null    int64
#  32  GET_ACCOUNTS
# READ_CALENDAR
# READ_CALL_LOG                   411 non-null    int64
#  33  READ_CALENDAR
# READ_CALL_LOG
# READ_CONTACTS                  411 non-null    int64
#  34  READ_CALL_LOG
# READ_CONTACTS
# READ_EXTERNAL_STORAGE          411 non-null    int64
#  35  READ_CONTACTS
# READ_EXTERNAL_STORAGE
# READ_PHONE_STATE       411 non-null    int64
#  36  READ_EXTERNAL_STORAGE
# READ_PHONE_STATE
# READ_SMS            411 non-null    int64
#  37  READ_PHONE_STATE
# READ_SMS
# RECEIVE_SMS                      411 non-null    int64
#  38  READ_SMS
# RECEIVE_SMS
# SEND_SMS                              411 non-null    int64
#  39  RECEIVE_SMS
# SEND_SMS
# WRITE_CALENDAR                        411 non-null    int64
#  40  SEND_SMS
# WRITE_CALENDAR
# WRITE_CALL_LOG                     411 non-null    int64
#  41  WRITE_CALENDAR
# WRITE_CALL_LOG
# ACCESS_MOCK_LOCATION         411 non-null    int64
#  42  WRITE_CALL_LOG
# ACCESS_MOCK_LOCATION
# ACCOUNT_MANAGER        411 non-null    int64
#  43  ACCESS_MOCK_LOCATION
# ACCOUNT_MANAGER
# ACCESS_NETWORK_STATE  411 non-null    int64
#  44  ACCOUNT_MANAGER
# ACCESS_NETWORK_STATE
# READ_VOICEMAIL        411 non-null    int64
#  45  Classe                                                     411 non-null    int64
# dtypes: float64(3), int64(43)
# memory usage: 147.8 KB

# %%
datamalw.describe()
# Out:
#            items      CAMERA  GET_ACCOUNTS  READ_CALENDAR  READ_CALL_LOG  \
# count  411.00000  411.000000    411.000000     411.000000     411.000000
# mean   206.00000    0.216545      0.107056       0.038929       0.021898
# std    118.78973    0.412392      0.309561       0.193663       0.146528
# min      1.00000    0.000000      0.000000       0.000000       0.000000
# 25%    103.50000    0.000000      0.000000       0.000000       0.000000
# 50%    206.00000    0.000000      0.000000       0.000000       0.000000
# 75%    308.50000    0.000000      0.000000       0.000000       0.000000
# max    411.00000    1.000000      1.000000       1.000000       1.000000
#
#        READ_CONTACTS  READ_EXTERNAL_STORAGE  READ_PHONE_STATE    READ_SMS  \
# count     411.000000             410.000000        410.000000  411.000000
# mean        0.065693               0.321951          0.229268    0.017032
# std         0.248047               0.467795          0.420876    0.129547
# min         0.000000               0.000000          0.000000    0.000000
# 25%         0.000000               0.000000          0.000000    0.000000
# 50%         0.000000               0.000000          0.000000    0.000000
# 75%         0.000000               1.000000          0.000000    0.000000
# max         1.000000               1.000000          1.000000    1.000000
#
#        RECEIVE_SMS  ...  READ_EXTERNAL_STORAGE\nREAD_PHONE_STATE\nREAD_SMS  \
# count   411.000000  ...                                              411.0
# mean      0.026764  ...                                                0.0
# std       0.161590  ...                                                0.0
# min       0.000000  ...                                                0.0
# 25%       0.000000  ...                                                0.0
# 50%       0.000000  ...                                                0.0
# 75%       0.000000  ...                                                0.0
# max       1.000000  ...                                                0.0
#
#        READ_PHONE_STATE\nREAD_SMS\nRECEIVE_SMS  \
# count                                    411.0
# mean                                       0.0
# std                                        0.0
# min                                        0.0
# 25%                                        0.0
# 50%                                        0.0
# 75%                                        0.0
# max                                        0.0
#
#        READ_SMS\nRECEIVE_SMS\nSEND_SMS  RECEIVE_SMS\nSEND_SMS\nWRITE_CALENDAR  \
# count                            411.0                                  411.0
# mean                               0.0                                    0.0
# std                                0.0                                    0.0
# min                                0.0                                    0.0
# 25%                                0.0                                    0.0
# 50%                                0.0                                    0.0
# 75%                                0.0                                    0.0
# max                                0.0                                    0.0
#
#        SEND_SMS\nWRITE_CALENDAR\nWRITE_CALL_LOG  \
# count                                     411.0
# mean                                        0.0
# std                                         0.0
# min                                         0.0
# 25%                                         0.0
# 50%                                         0.0
# 75%                                         0.0
# max                                         0.0
#
#        WRITE_CALENDAR\nWRITE_CALL_LOG\nACCESS_MOCK_LOCATION  \
# count                                              411.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        WRITE_CALL_LOG\nACCESS_MOCK_LOCATION\nACCOUNT_MANAGER  \
# count                                              411.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        ACCESS_MOCK_LOCATION\nACCOUNT_MANAGER\nACCESS_NETWORK_STATE  \
# count                                              411.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        ACCOUNT_MANAGER\nACCESS_NETWORK_STATE\nREAD_VOICEMAIL      Classe
# count                                              411.0      411.000000
# mean                                                 0.0        0.513382
# std                                                  0.0        0.500430
# min                                                  0.0        0.000000
# 25%                                                  0.0        0.000000
# 50%                                                  0.0        1.000000
# 75%                                                  0.0        1.000000
# max                                                  0.0        1.000000
#
# [8 rows x 46 columns]

# %%
import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
print(datamalw.Classe)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 406    0
# 407    0
# 408    0
# 409    0
# 410    0
# Name: Classe, Length: 411, dtype: int64

# %%
print('Example data: ')
print(datamalw.Classe)
# Out:
# Example data:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 406    0
# 407    0
# 408    0
# 409    0
# 410    0
# Name: Classe, Length: 411, dtype: int64

# %%
x = datamalw
y_ = datamalw.Classe # Convert data to a single column

# %%
print(iris_data.target[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a5636a84b10d> in <module>
# ----> 1 print(iris_data.target[:5])
#
# NameError: name 'iris_data' is not defined

# %%
encoder = OneHotEncoder(sparse=False)
y = y_
#y = encoder.fit_transform(y_)

# %%
# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# %%
model = Sequential()

# %%
model.add(Dense(2, input_shape=(46,46), activation='relu', name='fc1'))
model.add(Dense(2, activation='relu', name='fc2'))
model.add(Dense(1, activation='softmax', name='output'))

# %%
# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print('Neural Network Model Summary: ')
print(model.summary())
# Out:
# Neural Network Model Summary:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (Dense)                  (None, 46, 2)             94
# _________________________________________________________________
# fc2 (Dense)                  (None, 46, 2)             6
# _________________________________________________________________
# output (Dense)               (None, 46, 1)             3
# =================================================================
# Total params: 103
# Trainable params: 103
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=400)
# Out:
# Epoch 1/400
# WARNING:tensorflow:Model was constructed with shape (None, 46, 46) for input KerasTensor(type_spec=TensorSpec(shape=(None, 46, 46), dtype=tf.float32, name='fc1_input'), name='fc1_input', description="created by layer 'fc1_input'"), but it was called on an input with incompatible shape (None, 46).
# WARNING:tensorflow:Model was constructed with shape (None, 46, 46) for input KerasTensor(type_spec=TensorSpec(shape=(None, 46, 46), dtype=tf.float32, name='fc1_input'), name='fc1_input', description="created by layer 'fc1_input'"), but it was called on an input with incompatible shape (None, 46).
# 66/66 - 2s - loss: nan - accuracy: 0.5274
# Epoch 2/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 3/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 4/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 5/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 6/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 7/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 8/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 9/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 10/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 11/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 12/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 13/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 14/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 15/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 16/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 17/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 18/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 19/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 20/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 21/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 22/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 23/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 24/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 25/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 26/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 27/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 28/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 29/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 30/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 31/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 32/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 33/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 34/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 35/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 36/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 37/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 38/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 39/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 40/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 41/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 42/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 43/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 44/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 45/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 46/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 47/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 48/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 49/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 50/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 51/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 52/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 53/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 54/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 55/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 56/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 57/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 58/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 59/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 60/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 61/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 62/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 63/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 64/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 65/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 66/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 67/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 68/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 69/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 70/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 71/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 72/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 73/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 74/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 75/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 76/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 77/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 78/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 79/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 80/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 81/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 82/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 83/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 84/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 85/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 86/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 87/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 88/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 89/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 90/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 91/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 92/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 93/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 94/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 95/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 96/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 97/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 98/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 99/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 100/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 101/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 102/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 103/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 104/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 105/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 106/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 107/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 108/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 109/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 110/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 111/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 112/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 113/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 114/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 115/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 116/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 117/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 118/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 119/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 120/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 121/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 122/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 123/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 124/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 125/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 126/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 127/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 128/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 129/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 130/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 131/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 132/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 133/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 134/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 135/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 136/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 137/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 138/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 139/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 140/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 141/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 142/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 143/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 144/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 145/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 146/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 147/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 148/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 149/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 150/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 151/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 152/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 153/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 154/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 155/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 156/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 157/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 158/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 159/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 160/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 161/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 162/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 163/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 164/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 165/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 166/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 167/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 168/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 169/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 170/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 171/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 172/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 173/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 174/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 175/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 176/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 177/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 178/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 179/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 180/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 181/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 182/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 183/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 184/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 185/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 186/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 187/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 188/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 189/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 190/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 191/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 192/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 193/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 194/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 195/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 196/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 197/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 198/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 199/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 200/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 201/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 202/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 203/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 204/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 205/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 206/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 207/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 208/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 209/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 210/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 211/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 212/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 213/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 214/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 215/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 216/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 217/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 218/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 219/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 220/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 221/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 222/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 223/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 224/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 225/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 226/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 227/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 228/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 229/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 230/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 231/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 232/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 233/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 234/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 235/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 236/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 237/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 238/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 239/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 240/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 241/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 242/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 243/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 244/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 245/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 246/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 247/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 248/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 249/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 250/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 251/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 252/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 253/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 254/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 255/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 256/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 257/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 258/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 259/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 260/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 261/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 262/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 263/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 264/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 265/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 266/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 267/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 268/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 269/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 270/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 271/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 272/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 273/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 274/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 275/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 276/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 277/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 278/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 279/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 280/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 281/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 282/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 283/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 284/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 285/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 286/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 287/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 288/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 289/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 290/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 291/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 292/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 293/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 294/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 295/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 296/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 297/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 298/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 299/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 300/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 301/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 302/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 303/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 304/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 305/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 306/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 307/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 308/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 309/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 310/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 311/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 312/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 313/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 314/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 315/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 316/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 317/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 318/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 319/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 320/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 321/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 322/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 323/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 324/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 325/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 326/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 327/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 328/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 329/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 330/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 331/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 332/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 333/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 334/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 335/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 336/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 337/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 338/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 339/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 340/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 341/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 342/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 343/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 344/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 345/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 346/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 347/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 348/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 349/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 350/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 351/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 352/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 353/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 354/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 355/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 356/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 357/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 358/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 359/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 360/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 361/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 362/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 363/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 364/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 365/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 366/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 367/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 368/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 369/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 370/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 371/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 372/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 373/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 374/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 375/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 376/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 377/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 378/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 379/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 380/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 381/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 382/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 383/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 384/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 385/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 386/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 387/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 388/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 389/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 390/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 391/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 392/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 393/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 394/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 395/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 396/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 397/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 398/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 399/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878
# Epoch 400/400
# 66/66 - 0s - loss: nan - accuracy: 0.4878

# %%
# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=2, epochs=400)
# Out:
# Epoch 1/400
# WARNING:tensorflow:Model was constructed with shape (None, 46, 46) for input KerasTensor(type_spec=TensorSpec(shape=(None, 46, 46), dtype=tf.float32, name='fc1_input'), name='fc1_input', description="created by layer 'fc1_input'"), but it was called on an input with incompatible shape (2, 46).
# 164/164 - 1s - loss: nan - accuracy: 0.4878
# Epoch 2/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 3/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 4/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 5/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 6/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 7/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 8/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 9/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 10/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 11/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 12/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 13/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 14/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 15/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 16/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 17/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 18/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 19/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 20/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 21/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 22/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 23/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 24/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 25/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 26/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 27/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 28/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 29/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 30/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 31/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 32/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 33/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 34/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 35/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 36/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 37/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 38/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 39/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 40/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 41/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 42/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 43/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 44/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 45/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 46/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 47/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 48/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 49/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 50/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 51/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 52/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 53/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 54/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 55/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 56/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 57/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 58/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 59/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 60/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 61/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 62/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 63/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 64/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 65/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 66/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 67/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 68/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 69/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 70/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 71/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 72/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 73/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 74/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 75/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 76/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 77/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 78/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 79/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 80/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 81/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 82/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 83/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 84/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 85/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 86/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 87/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 88/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 89/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 90/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 91/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 92/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 93/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 94/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 95/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 96/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 97/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 98/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 99/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 100/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 101/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 102/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 103/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 104/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 105/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 106/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 107/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 108/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 109/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 110/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 111/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 112/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 113/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 114/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 115/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 116/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 117/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 118/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 119/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 120/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 121/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 122/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 123/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 124/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 125/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 126/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 127/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 128/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 129/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 130/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 131/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 132/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 133/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 134/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 135/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 136/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 137/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 138/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 139/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 140/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 141/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 142/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 143/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 144/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 145/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 146/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 147/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 148/400
# 164/164 - 1s - loss: nan - accuracy: 0.4878
# Epoch 149/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 150/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 151/400
# 164/164 - 1s - loss: nan - accuracy: 0.4878
# Epoch 152/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 153/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 154/400
# 164/164 - 1s - loss: nan - accuracy: 0.4878
# Epoch 155/400
# 164/164 - 1s - loss: nan - accuracy: 0.4878
# Epoch 156/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 157/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 158/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 159/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 160/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 161/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 162/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 163/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 164/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 165/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 166/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 167/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 168/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 169/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 170/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 171/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 172/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 173/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 174/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 175/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 176/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 177/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 178/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 179/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 180/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 181/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 182/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 183/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 184/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 185/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 186/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 187/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 188/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 189/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 190/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 191/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 192/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 193/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 194/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 195/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 196/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 197/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 198/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 199/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 200/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 201/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 202/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 203/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 204/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 205/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 206/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 207/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 208/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 209/400
# 164/164 - 1s - loss: nan - accuracy: 0.4878
# Epoch 210/400
# 164/164 - 1s - loss: nan - accuracy: 0.4878
# Epoch 211/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 212/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 213/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 214/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 215/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 216/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 217/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 218/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 219/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 220/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 221/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 222/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 223/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 224/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 225/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 226/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 227/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 228/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 229/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 230/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 231/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 232/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 233/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 234/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 235/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 236/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 237/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 238/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 239/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 240/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 241/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 242/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 243/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 244/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 245/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 246/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 247/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 248/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 249/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 250/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 251/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 252/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 253/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 254/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 255/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 256/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 257/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 258/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 259/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 260/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 261/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 262/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 263/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 264/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 265/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 266/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 267/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 268/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 269/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 270/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 271/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 272/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 273/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 274/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 275/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 276/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 277/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 278/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 279/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 280/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 281/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 282/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 283/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 284/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 285/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 286/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 287/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 288/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 289/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 290/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 291/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 292/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 293/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 294/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 295/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 296/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 297/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 298/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 299/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 300/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 301/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 302/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 303/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 304/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 305/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 306/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 307/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 308/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 309/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 310/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 311/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 312/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 313/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 314/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 315/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 316/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 317/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 318/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 319/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 320/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 321/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 322/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 323/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 324/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 325/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 326/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 327/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 328/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 329/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 330/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 331/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 332/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 333/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 334/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 335/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 336/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 337/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 338/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 339/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 340/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 341/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 342/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 343/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 344/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 345/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 346/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 347/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 348/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 349/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 350/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 351/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 352/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 353/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 354/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 355/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 356/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 357/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 358/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 359/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 360/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 361/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 362/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 363/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 364/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 365/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 366/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 367/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 368/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 369/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 370/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 371/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 372/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 373/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 374/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 375/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 376/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 377/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 378/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 379/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 380/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 381/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 382/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 383/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 384/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 385/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 386/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 387/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 388/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 389/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 390/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 391/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 392/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 393/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 394/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 395/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 396/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 397/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 398/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 399/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878
# Epoch 400/400
# 164/164 - 0s - loss: nan - accuracy: 0.4878

# %%
results = model.evaluate(test_x, test_y)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 46, 46) for input KerasTensor(type_spec=TensorSpec(shape=(None, 46, 46), dtype=tf.float32, name='fc1_input'), name='fc1_input', description="created by layer 'fc1_input'"), but it was called on an input with incompatible shape (None, 46).
# 3/3 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.4819

# %%
print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# Final test set loss:  nan
# Final test set accuracy: 0.421687

# %%
"""
    A simple neural network written in Keras (TensorFlow backend) to classify the IRIS data
"""

import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

iris_data = load_iris() # load the iris dataset

print('Example data: ')
print(data.data[:5])
print('Example labels: ')
print(iris_data.target[:5])

x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column

# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)
#print(y)

# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# Build the model

model = Sequential()

model.add(Dense(10, input_shape=(4,), activation='relu', name='fc1'))
model.add(Dense(10, activation='relu', name='fc2'))
model.add(Dense(3, activation='softmax', name='output'))

# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())

# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)

# Test on unseen data

results = model.evaluate(test_x, test_y)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))

# %%
# LSTM model

# %%
import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam

# %%
x = datamalw
y_ = datamalw.Classe # Convert data to a single column

# %%
encoder = OneHotEncoder(sparse=False)
y = y_
#y = encoder.fit_transform(y_)

# %%
# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# %%
model = Sequential()

# %%
#model.add(Dense(46, input_shape=(46,46), activation='relu', name='fc0'))
model.add(LSTM( input_shape=(1,1,), activation='relu', name='fc1'))
model.add(Dense(1, activation='relu', name='fc2'))
#model.add(Dense(1, activation='relu', name='fc3'))
model.add(Dense(1, activation='softmax', name='output'))
#model.add(LSTM((46), batch_input_shape=(1,5,1), return_sequences=False))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-e558132b2d94> in <module>
#       1 #model.add(Dense(46, input_shape=(46,46), activation='relu', name='fc0'))
# ----> 2 model.add(LSTM( input_shape=(1,1,0), activation='relu', name='fc1'))
#       3 model.add(Dense(1, activation='relu', name='fc2'))
#       4 #model.add(Dense(1, activation='relu', name='fc3'))
#       5 model.add(Dense(1, activation='softmax', name='output'))
#
# TypeError: __init__() missing 1 required positional argument: 'units'

# %%
# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print('Neural Network Model Summary: ')
print(model.summary())
# Out:
# Neural Network Model Summary:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc1 (LSTM)                   (None, 1)                 12
# _________________________________________________________________
# fc2 (Dense)                  (None, 1)                 2
# _________________________________________________________________
# output (Dense)               (None, 1)                 2
# =================================================================
# Total params: 16
# Trainable params: 16
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)
# Out:
# Epoch 1/200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-f8bcdcfb31d1> in <module>
#       1 # Train the model
# ----> 2 model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)
#
# ~/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     869       # This is the first call of __call__, so we have to initialize.
#     870       initializers = []
# --> 871       self._initialize(args, kwds, add_initializers_to=initializers)
#     872     finally:
#     873       # At this point we know that the initialization is complete (or less
#
# ~/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     723     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     724     self._concrete_stateful_fn = (
# --> 725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     726             *args, **kwds))
#     727
#
# ~/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# ~/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# ~/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3194     arg_names = base_arg_names + missing_arg_names
#    3195     graph_function = ConcreteFunction(
# -> 3196         func_graph_module.func_graph_from_py_func(
#    3197             self._name,
#    3198             self._python_function,
#
# ~/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# ~/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# ValueError: in user code:
#
#     /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:805 train_function  *
#         return step_function(self, iterator)
#     /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:795 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:788 run_step  **
#         outputs = model.train_step(data)
#     /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:754 train_step
#         y_pred = self(x, training=True)
#     /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /home/varmant-charles/anaconda3/envs/conda_env/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_spec.py:219 assert_input_compatibility
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer sequential_1 is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 46)

# %%
#other test
